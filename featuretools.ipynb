# %%
import pandas as pd
import featuretools as ft

# %%
clients = pd.read_csv('data/clients.csv', parse_dates=['joined'])
loans = pd.read_csv('data/loans.csv', parse_dates=['loan_start', 'loan_end'])
payments = pd.read_csv('data/payments.csv', parse_dates=['payment_date'])

# %%
clients.head(1)
# Out:
#    client_id     joined  income  credit_score
# 0      46109 2002-04-16  172677           527

# %%
loans.head(1)
# Out:
#    client_id loan_type  loan_amount  repaid  loan_id loan_start   loan_end  \
# 0      46109      home        13672       0    10243 2002-04-16 2003-12-20
#
#    rate
# 0  2.15

# %%
payments.head(1)
# Out:
#    loan_id  payment_amount payment_date  missed
# 0    10243            2369   2002-05-31       1

# %% [markdown]
# ## Create new entityset

# %%
es = ft.EntitySet(id='clients')

# %% [markdown]
# ## Add entities

# %%
es = es.entity_from_dataframe(entity_id='clients', dataframe=clients,
                              index='client_id', time_index='joined')
es = es.entity_from_dataframe(entity_id='loans', dataframe=loans,
                              variable_types={'repaid': ft.variable_types.Categorical},
                              index='loan_id', time_index='loan_start')
es = es.entity_from_dataframe(entity_id='payments', dataframe=payments,
                              variable_types={'missed': ft.variable_types.Categorical},
                              #make_index=True,
                              index='payment_id',
                              time_index='payment_date')

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 5]
#     loans [Rows: 443, Columns: 9]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     No relationships

# %%
es['clients']
# Out:
# Entity: clients
#   Variables:
#     client_id (dtype: index)
#     clients_id (dtype: numeric)
#     joined (dtype: datetime_time_index)
#     income (dtype: numeric)
#     credit_score (dtype: numeric)
#   Shape:
#     (Rows: 25, Columns: 5)

# %%
es['loans']
# Out:
# Entity: loans
#   Variables:
#     loan_id (dtype: index)
#     loans_id (dtype: numeric)
#     client_id (dtype: numeric)
#     loan_type (dtype: categorical)
#     loan_amount (dtype: numeric)
#     loan_start (dtype: datetime_time_index)
#     loan_end (dtype: datetime)
#     rate (dtype: numeric)
#     repaid (dtype: categorical)
#   Shape:
#     (Rows: 443, Columns: 9)

# %%
es['payments']
# Out:
# Entity: payments
#   Variables:
#     payment_id (dtype: index)
#     loan_id (dtype: numeric)
#     payment_amount (dtype: numeric)
#     payment_date (dtype: datetime_time_index)
#     missed (dtype: categorical)
#   Shape:
#     (Rows: 3456, Columns: 5)

# %% [markdown]
# ## Relationship

# %%
r_clients = ft.Relationship(es['clients']['client_id'], es['loans']['client_id'])
es = es.add_relationship(r_clients)
r_payments = ft.Relationship(es['loans']['loan_id'], es['payments']['loan_id'])
es = es.add_relationship(r_payments)

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 5]
#     loans [Rows: 443, Columns: 9]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id
#     payments.loan_id -> loans.loan_id

# %% [markdown]
# ## Feature Primitives

# %%
primitives = ft.list_primitives()
primitives[primitives['type']=='aggregation']
# Out:
#                 name         type  \
# 0                all  aggregation
# 1              count  aggregation
# 2               last  aggregation
# 3               skew  aggregation
# 4      n_most_common  aggregation
# 5               mode  aggregation
# 6         num_unique  aggregation
# 7    time_since_last  aggregation
# 8                sum  aggregation
# 9             median  aggregation
# 10               any  aggregation
# 11               std  aggregation
# 12  avg_time_between  aggregation
# 13      percent_true  aggregation
# 14          num_true  aggregation
# 15              mean  aggregation
# 16             trend  aggregation
# 17               max  aggregation
# 18               min  aggregation
#
#                                                                 description
# 0                                            Test if all values are 'True'.
# 1                                     Counts the number of non null values.
# 2                                                   Returns the last value.
# 3                                      Computes the skewness of a data set.
# 4                Finds the N most common elements in a categorical feature.
# 5                   Finds the most common element in a categorical feature.
# 6                       Returns the number of unique categorical variables.
# 7                                         Time since last related instance.
# 8                            Sums elements of a numeric or boolean feature.
# 9           Finds the median value of any feature with well-ordered values.
# 10                                             Test if any value is 'True'.
# 11  Finds the standard deviation of a numeric feature ignoring null values.
# 12                    Computes the average time between consecutive events.
# 13                 Finds the percent of 'True' values in a boolean feature.
# 14                          Finds the number of 'True' values in a boolean.
# 15                         Computes the average value of a numeric feature.
# 16           Calculates the slope of the linear trend of variable overtime.
# 17                   Finds the maximum non-null value of a numeric feature.
# 18                   Finds the minimum non-null value of a numeric feature.

# %%
primitives[primitives['type']=='transform']
# Out:
#                    name       type  \
# 19           characters  transform
# 20                 hour  transform
# 21                  and  transform
# 22             latitude  transform
# 23              weekday  transform
# 24              is_null  transform
# 25           days_since  transform
# 26            haversine  transform
# 27              cum_min  transform
# 28              weekend  transform
# 29               months  transform
# 30               divide  transform
# 31                  mod  transform
# 32                hours  transform
# 33              minutes  transform
# 34           time_since  transform
# 35                weeks  transform
# 36                  not  transform
# 37              seconds  transform
# 38               second  transform
# 39             numwords  transform
# 40                   or  transform
# 41                 week  transform
# 42             cum_mean  transform
# 43                 diff  transform
# 44                  day  transform
# 45             multiply  transform
# 46           percentile  transform
# 47                 isin  transform
# 48                 year  transform
# 49              cum_max  transform
# 50               minute  transform
# 51                years  transform
# 52            cum_count  transform
# 53                  add  transform
# 54                month  transform
# 55             absolute  transform
# 56              cum_sum  transform
# 57            longitude  transform
# 58             subtract  transform
# 59  time_since_previous  transform
# 60                 days  transform
# 61               negate  transform
#
#                                                                                            description
# 19                                                            Return the characters in a given string.
# 20                                                         Transform a Datetime feature into the hour.
# 21                                        For two boolean values, determine if both values are 'True'.
# 22                                                  Returns the first value of the tuple base feature.
# 23                                             Transform Datetime feature into the boolean of Weekday.
# 24                                     For each value of base feature, return 'True' if value is null.
# 25                           For each value of the base feature, compute the number of days between it
# 26           Calculate the approximate haversine distance in miles between two LatLong variable types.
# 27     Calculates the min of previous values of an instance for each value in a time-dependent entity.
# 28                                             Transform Datetime feature into the boolean of Weekend.
# 29                                            Transform a Timedelta feature into the number of months.
# 30                                              Creates a transform feature that divides two features.
# 31                                              Creates a transform feature that divides two features.
# 32                                             Transform a Timedelta feature into the number of hours.
# 33                                           Transform a Timedelta feature into the number of minutes.
# 34                                                              Calculates time since the cutoff time.
# 35                                             Transform a Timedelta feature into the number of weeks.
# 36                                      For each value of the base feature, negates the boolean value.
# 37                                           Transform a Timedelta feature into the number of seconds.
# 38                                                       Transform a Datetime feature into the second.
# 39                                         Returns the words in a given string by counting the spaces.
# 40                                           For two boolean values, determine if one value is 'True'.
# 41                                                         Transform a Datetime feature into the week.
# 42    Calculates the mean of previous values of an instance for each value in a time-dependent entity.
# 43                  Compute the difference between the value of a base feature and the previous value.
# 44                                                          Transform a Datetime feature into the day.
# 45                                            Creates a transform feature that multplies two features.
# 46                           For each value of the base feature, determines the percentile in relation
# 47                        For each value of the base feature, checks whether it is in a provided list.
# 48                                                         Transform a Datetime feature into the year.
# 49     Calculates the max of previous values of an instance for each value in a time-dependent entity.
# 50                                                       Transform a Datetime feature into the minute.
# 51                                             Transform a Timedelta feature into the number of years.
# 52  Calculates the number of previous values of an instance for each value in a time-dependent entity.
# 53                                                 Creates a transform feature that adds two features.
# 54                                                        Transform a Datetime feature into the month.
# 55                                                                     Absolute value of base feature.
# 56     Calculates the sum of previous values of an instance for each value in a time-dependent entity.
# 57                                                 Returns the second value on the tuple base feature.
# 58                                            Creates a transform feature that subtracts two features.
# 59                                                       Compute the time since the previous instance.
# 60                                              Transform a Timedelta feature into the number of days.
# 61                                                 Creates a transform feature that negates a feature.

# %%
features, feature_names = ft.dfs(entityset=es, target_entity='clients',
                                        agg_primitives=['mean', 'max', 'percent_true', 'last'],
                                        trans_primitives=['years', 'month', 'subtract', 'divide'])

# %%
clients.head(1)
# Out:
#    clients_id  client_id     joined  income  credit_score
# 0           0      46109 2002-04-16  172677           527

# %%
features.head(1)
# Out:
#            clients_id  income  credit_score  MEAN(loans.loans_id)  \
# client_id
# 25707               4  211422           621                  89.5
#
#            MEAN(loans.loan_amount)  MEAN(loans.rate)  MAX(loans.loans_id)  \
# client_id
# 25707                      7963.95             3.477                   99
#
#            MAX(loans.loan_amount)  MAX(loans.rate)  LAST(loans.loans_id)  \
# client_id
# 25707                       13913             9.44                    83
#
#                         ...                \
# client_id               ...
# 25707                   ...
#
#           MAX(loans.loan_amount) / MAX(loans.loans_id)  \
# client_id
# 25707                                       140.535354
#
#            income / LAST(payments.payment_amount)  \
# client_id
# 25707                                   877.26971
#
#            LAST(loans.loan_amount) / MEAN(payments.payment_amount)  \
# client_id
# 25707                                                     1.869242
#
#            LAST(loans.rate) / MEAN(payments.payment_amount)  \
# client_id
# 25707                                              0.006279
#
#            credit_score - clients_id / income - clients_id  \
# client_id
# 25707                                             0.002918
#
#            clients_id - income / MAX(payments.payment_amount)  \
# client_id
# 25707                                               -78.18713
#
#            LAST(loans.rate) / clients_id  \
# client_id
# 25707                               1.85
#
#            MAX(loans.loan_amount) / credit_score - income  \
# client_id
# 25707                                           -0.066001
#
#            LAST(loans.loans_id) / credit_score - clients_id  \
# client_id
# 25707                                              0.134522
#
#            income / credit_score - income
# client_id
# 25707                           -1.002946
#
# [1 rows x 697 columns]

# %%
features['MONTH(joined)'].head()
# Out:
# client_id
# 25707    10
# 26326     5
# 26695     8
# 26945    11
# 29841     8
# Name: MONTH(joined), dtype: int64

# %% [markdown]
# ## Deep Feature Synthesis

# %%
# Show a feature with a depth of 2
pd.DataFrame(features['LAST(loans.MEAN(payments.payment_amount))'].head(10))
# Out:
#            LAST(loans.MEAN(payments.payment_amount))
# client_id
# 25707                                     293.500000
# 26326                                     977.375000
# 26695                                    1769.166667
# 26945                                    1598.666667
# 29841                                    1125.500000
# 32726                                     799.500000
# 32885                                    1729.000000
# 32961                                     282.600000
# 35089                                     110.400000
# 35214                                    1410.250000

# %% [markdown]
# the LAST(loans.(MEAN(payments.payment_amount))) has depth = 2 because it is made by stacking two feature primitives, first an aggregation and then a transformation. This feature represents the average payment amount for the last (most recent) loan for each client.

# %% [markdown]
# ## Automated Deep Feature Synthesis

# %%
# Perform deep feature synthesis without specifying primitives
features, feature_names = ft.dfs(entityset=es, target_entity='clients', max_depth = 2)

# %%
features
# Out:
#            clients_id  income  credit_score  SUM(loans.loans_id)  \
# client_id
# 25707               4  211422           621                 1790
# 26326              10  227920           633                 3256
# 26695              19  174532           680                 6435
# 26945              24  214516           806                 6525
# 29841              13   38354           523                 4545
# 32726               6  235705           730                 2451
# 32885              15   58955           642                 4335
# 32961              12  230341           714                 3995
# 35089               7  131176           771                 2970
# 35214               8   95849           696                 3015
# 38537              20  127183           643                 6375
# 39384              18  191204           617                 6441
# 39505               5  153873           610                 2190
# 41472              22  152214           638                 6472
# 41480               2  122607           585                  990
# 42320              11  229481           563                 3285
# 44387              17  151903           781                 4830
# 44601              14  156341           518                 5430
# 46109               0  172677           527                  190
# 46180               3   43851           562                 1390
# 46958              21  225709           644                 5070
# 48177               9  190632           769                 3534
# 49068              16  128813           603                 5499
# 49545               1  104564           770                  590
# 49624              23   49036           800                 6300
#
#            SUM(loans.loan_amount)  SUM(loans.rate)  STD(loans.loans_id)  \
# client_id
# 25707                      159279            69.54             5.916080
# 26326                      116321            40.28             4.760952
# 26695                      140845            44.39             5.338539
# 26945                      106889            42.83             4.472136
# 29841                      176634            62.01             5.338539
# 32726                      126032            58.12             5.627314
# 32885                      148806            36.54             4.472136
# 32961                      133998            66.82             5.049752
# 35089                      138784            70.27             5.916080
# 35214                      129124            55.95             5.338539
# 38537                      152768            40.62             5.049752
# 39384                      149444            67.23             5.627314
# 39505                      148481            63.81             5.916080
# 41472                      120173            63.70             4.760952
# 41480                      157897            62.21             5.916080
# 42320                      105931            36.86             4.472136
# 44387                      110816            42.10             4.472136
# 44601                      137385            83.02             5.916080
# 46109                      179032            63.05             5.916080
# 46180                      154017            70.05             5.916080
# 46958                      121919            41.00             3.894440
# 48177                      141063            74.84             5.627314
# 49068                      137122            55.72             5.338539
# 49545                      205786            53.68             5.916080
# 49624                      137618            60.56             4.472136
#
#            STD(loans.loan_amount)  STD(loans.rate)  MAX(loans.loans_id)  \
# client_id
# 25707                 4149.486062         2.484186                   99
# 26326                 4393.666631         2.057142                  211
# 26695                 4196.462499         1.561659                  366
# 26945                 4543.621769         1.619717                  442
# 29841                 4209.224171         2.122904                  261
# 32726                 4516.148677         1.985567                  138
# 32885                 3205.122414         2.771696                  296
# 32961                 4968.314220         2.753583                  243
# 35089                 3747.544257         2.210354                  158
# 35214                 3991.869490         2.366296                  176
# 38537                 4658.103717         2.166649                  383
# 39384                 3964.286840         2.629599                  348
# 39505                 4612.033990         2.925459                  119
# 41472                 4257.668536         3.198366                  412
# 41480                 4427.148486         2.971777                   59
# 42320                 4165.826885         1.984938                  226
# 44387                 4356.647916         1.769535                  329
# 44601                 3346.342510         2.372345                  281
# 46109                 4037.777260         2.352222                   19
# 46180                 3835.726436         2.550263                   79
# 46958                 3879.517851         1.913124                  396
# 48177                 4346.240485         2.803066                  195
# 49068                 4129.214152         2.182304                  314
# 49545                 3517.554131         2.001493                   39
# 49624                 4270.906375         3.094291                  427
#
#                        ...                NUM_UNIQUE(loans.WEEKDAY(loan_end))  \
# client_id              ...
# 25707                  ...                                                  6
# 26326                  ...                                                  5
# 26695                  ...                                                  6
# 26945                  ...                                                  6
# 29841                  ...                                                  7
# 32726                  ...                                                  7
# 32885                  ...                                                  6
# 32961                  ...                                                  7
# 35089                  ...                                                  7
# 35214                  ...                                                  5
# 38537                  ...                                                  6
# 39384                  ...                                                  7
# 39505                  ...                                                  7
# 41472                  ...                                                  6
# 41480                  ...                                                  6
# 42320                  ...                                                  5
# 44387                  ...                                                  7
# 44601                  ...                                                  7
# 46109                  ...                                                  7
# 46180                  ...                                                  6
# 46958                  ...                                                  7
# 48177                  ...                                                  7
# 49068                  ...                                                  7
# 49545                  ...                                                  7
# 49624                  ...                                                  5
#
#            MODE(loans.MODE(payments.missed))  MODE(loans.DAY(loan_start))  \
# client_id
# 25707                                      0                           27
# 26326                                      0                            6
# 26695                                      0                            3
# 26945                                      0                           16
# 29841                                      1                            1
# 32726                                      0                            2
# 32885                                      0                           13
# 32961                                      0                            6
# 35089                                      0                            4
# 35214                                      1                            9
# 38537                                      0                            2
# 39384                                      0                           29
# 39505                                      0                           22
# 41472                                      0                           27
# 41480                                      0                           29
# 42320                                      0                           13
# 44387                                      0                            3
# 44601                                      0                            7
# 46109                                      0                           12
# 46180                                      0                            3
# 46958                                      0                           10
# 48177                                      0                            7
# 49068                                      0                            3
# 49545                                      1                           13
# 49624                                      0                           26
#
#            MODE(loans.DAY(loan_end))  MODE(loans.YEAR(loan_start))  \
# client_id
# 25707                              1                          2010
# 26326                              6                          2003
# 26695                             14                          2003
# 26945                              1                          2002
# 29841                             15                          2005
# 32726                              1                          2004
# 32885                             12                          2007
# 32961                             19                          2001
# 35089                             15                          2003
# 35214                              2                          2007
# 38537                              1                          2012
# 39384                              7                          2007
# 39505                              5                          2004
# 41472                             22                          2001
# 41480                              8                          2005
# 42320                              6                          2002
# 44387                              1                          2005
# 44601                              4                          2003
# 46109                              5                          2006
# 46180                             14                          2000
# 46958                             21                          2001
# 48177                              8                          2009
# 49068                              2                          2012
# 49545                             30                          2001
# 49624                              4                          2003
#
#            MODE(loans.YEAR(loan_end))  MODE(loans.MONTH(loan_start))  \
# client_id
# 25707                            2007                              1
# 26326                            2005                              4
# 26695                            2005                              9
# 26945                            2004                             12
# 29841                            2007                              3
# 32726                            2004                              3
# 32885                            2009                              9
# 32961                            2014                              6
# 35089                            2014                              4
# 35214                            2005                              2
# 38537                            2006                              7
# 39384                            2016                              3
# 39505                            2006                              1
# 41472                            2004                              4
# 41480                            2007                              6
# 42320                            2007                             12
# 44387                            2007                              2
# 44601                            2011                              4
# 46109                            2007                              9
# 46180                            2005                             11
# 46958                            2004                              3
# 48177                            2009                             10
# 49068                            2014                              3
# 49545                            2003                              4
# 49624                            2005                              5
#
#            MODE(loans.MONTH(loan_end))  MODE(loans.WEEKDAY(loan_start))  \
# client_id
# 25707                                8                                3
# 26326                                7                                5
# 26695                                4                                1
# 26945                                5                                0
# 29841                                2                                5
# 32726                                9                                2
# 32885                                6                                4
# 32961                                6                                5
# 35089                                8                                3
# 35214                                5                                2
# 38537                               10                                2
# 39384                               10                                0
# 39505                                1                                3
# 41472                                8                                0
# 41480                                1                                5
# 42320                                4                                6
# 44387                                6                                3
# 44601                                3                                0
# 46109                                8                                2
# 46180                                5                                5
# 46958                                3                                3
# 48177                                1                                3
# 49068                                9                                6
# 49545                                3                                1
# 49624                               12                                0
#
#            MODE(loans.WEEKDAY(loan_end))
# client_id
# 25707                                  0
# 26326                                  2
# 26695                                  1
# 26945                                  1
# 29841                                  1
# 32726                                  6
# 32885                                  5
# 32961                                  6
# 35089                                  2
# 35214                                  5
# 38537                                  1
# 39384                                  6
# 39505                                  5
# 41472                                  2
# 41480                                  4
# 42320                                  0
# 44387                                  5
# 44601                                  1
# 46109                                  6
# 46180                                  6
# 46958                                  3
# 48177                                  0
# 49068                                  1
# 49545                                  5
# 49624                                  4
#
# [25 rows x 99 columns]
